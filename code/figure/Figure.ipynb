# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.bar(np.arange(1,6), np.array([6449, 4605, 9242, 22838, 96859]))

plt.title('Rating count')
plt.show()

# %%
plt.figure()
plt.bar(np.arange(2011,2019), np.array([7351, 10351, 23375, 28438, 32230, 22215, 13145, 2888]))

plt.title('Number of reviews in each year')
plt.show()

# %%
plt.figure()
plt.bar(np.arange(2011,2019), np.array([4.241327710515576, 4.309342092551445, 4.387422459893048, 4.4331528236866165, 4.4850776502363265, 4.410726511981742, 4.384349030470914]))

plt.title('Average rating of each year')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-64ba6cc51bd4> in <module>
#       1 plt.figure()
# ----> 2 plt.bar(np.arange(2011,2019), np.array([4.241327710515576, 4.309342092551445, 4.387422459893048, 4.4331528236866165, 4.4850776502363265, 4.410726511981742, 4.384349030470914]))
#       3
#       4 plt.title('Average rating of each year')
#       5 plt.show()
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
# -> 2489         **({"data": data} if data is not None else {}), **kwargs)
#    2490
#    2491
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
# ...
